# %%
from google.colab import drive
drive.mount("/content/gdrive")

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-d0d50402-aef0-4870-893c-e13fc1b8af8a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d0d50402-aef0-4870-893c-e13fc1b8af8a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving gender.csv to gender.csv
# Saving spotify10.csv to spotify10 (1).csv

# %%
from google.colab import files
uploaded= files.upload()

# %%
df = pd.read_csv("spotify10.csv", encoding='cp1252', error_bad_lines=False)

# %%
df
# Out:
#      Unnamed: 0                                              title  ... spch pop
# 0             1                                   Hey, Soul Sister  ...    4  83
# 1             2                               Love The Way You Lie  ...   23  82
# 2             3                                            TiK ToK  ...   14  80
# 3             4                                        Bad Romance  ...    4  79
# 4             5                               Just the Way You Are  ...    4  78
# ..          ...                                                ...  ...  ...  ..
# 598         599                Find U Again (feat. Camila Cabello)  ...    3  75
# 599         600      Cross Me (feat. Chance the Rapper & PnB Rock)  ...   12  75
# 600         601  No Brainer (feat. Justin Bieber, Chance the Ra...  ...   34  70
# 601         602    Nothing Breaks Like a Heart (feat. Miley Cyrus)  ...    7  69
# 602         603                                   Kills You Slowly  ...    6  67
#
# [603 rows x 15 columns]

# %%
df2 = pd.read_csv('gender.csv', encoding='latin1')

# %%
df
# Out:
#      Unnamed: 0                                              title  ... spch pop
# 0             1                                   Hey, Soul Sister  ...    4  83
# 1             2                               Love The Way You Lie  ...   23  82
# 2             3                                            TiK ToK  ...   14  80
# 3             4                                        Bad Romance  ...    4  79
# 4             5                               Just the Way You Are  ...    4  78
# ..          ...                                                ...  ...  ...  ..
# 598         599                Find U Again (feat. Camila Cabello)  ...    3  75
# 599         600      Cross Me (feat. Chance the Rapper & PnB Rock)  ...   12  75
# 600         601  No Brainer (feat. Justin Bieber, Chance the Ra...  ...   34  70
# 601         602    Nothing Breaks Like a Heart (feat. Miley Cyrus)  ...    7  69
# 602         603                                   Kills You Slowly  ...    6  67
#
# [603 rows x 15 columns]

# %%
df2
# Out:
#                  artist  gender                       category
# 0              12 Gauge    male  African-American_male_rappers
# 1                  1987    male           Swedish_male_singers
# 2              2 Chainz    male  African-American_male_rappers
# 3             2 Pistols    male  African-American_male_rappers
# 4             21 Savage    male  African-American_male_rappers
# ...                 ...     ...                            ...
# 23172     Øystein Sunde    male                Male_guitarists
# 23173      Øyvind Nypan    male                Male_guitarists
# 23174  Úna MacLochlainn  female           Irish_female_singers
# 23175      Úna Palliser  female           Irish_female_singers
# 23176      ?ebnem Ferah  female            Female_rock_singers
#
# [23177 rows x 3 columns]

# %%
df3 = pd.merge(df, df2, on="artist", how="left")

# %%
df3
# Out:
#      Unnamed: 0  ...                            category
# 0             1  ...                                 NaN
# 1             2  ...               American_male_rappers
# 2             3  ...  American_female_singer-songwriters
# 3             4  ...         American_female_pop_singers
# 4             5  ...    American_male_singer-songwriters
# ..          ...  ...                                 ...
# 598         599  ...                English_male_singers
# 599         600  ...                English_male_singers
# 600         601  ...                                 NaN
# 601         602  ...                English_male_singers
# 602         603  ...                                 NaN
#
# [603 rows x 17 columns]

# %%
df3 = df3.loc[:, ~df3.columns.str.contains('^Unnamed')]

# %%
del df3['category']

# %%
df3
# Out:
#                                                  title  ...  gender
# 0                                     Hey, Soul Sister  ...     NaN
# 1                                 Love The Way You Lie  ...    male
# 2                                              TiK ToK  ...  female
# 3                                          Bad Romance  ...  female
# 4                                 Just the Way You Are  ...    male
# ..                                                 ...  ...     ...
# 598                Find U Again (feat. Camila Cabello)  ...    male
# 599      Cross Me (feat. Chance the Rapper & PnB Rock)  ...    male
# 600  No Brainer (feat. Justin Bieber, Chance the Ra...  ...     NaN
# 601    Nothing Breaks Like a Heart (feat. Miley Cyrus)  ...    male
# 602                                   Kills You Slowly  ...     NaN
#
# [603 rows x 15 columns]

# %%
df3.to_csv('spdata.csv')
files.download('spdata.csv')
